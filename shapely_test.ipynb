# %%
from shapely import Point, LineString, Polygon, GeometryCollection

from data_generation import *

# %%
env = generate_random_polygon_env(n_env=1, add_walls=True, add_holes=True)

env.plot_environment()
# Out:
# (<Figure size 659.644x878.981 with 1 Axes>, <AxesSubplot:>)

# %%
pol = generate_random_polygon()

polygon = Polygon(pol)

# %%
polygon.bounds
# Out:
# (-1.312926653777373, -0.8610054681550385, 1.05720234978793, 1.1565344210952675)

# %%
polygon
# Out:
# <POLYGON ((0.598 0.962, 1.683 0.327, 0.621 -0.395, 0.447 -1.482, -0.79 -1.11...>

# %%
polygon
# Out:
# <POLYGON ((0.621 -0.395, 1.683 0.327, 0.598 0.962, -0.22 0.391, -0.866 0.082...>

# %%
line = LineString([(0, 0), (0.2, 0.1)])

# %%
line
# Out:
# <LINESTRING (0 0, 0.2 0.1)>

# %%
polygon.relate(line)
# Out:
# '102FF1FF2'
